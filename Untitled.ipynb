# %% [markdown]
# # importing important libaries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("heart_disease_data.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.shape
# Out:
# (303, 14)

# %%
# statistical measure about the data
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df["target"].unique()
# Out:
# array([1, 0])

# %%
df["sex"].unique()
# Out:
# array([1, 0])

# %%
df["age"].unique()
# Out:
# array([63, 37, 41, 56, 57, 44, 52, 54, 48, 49, 64, 58, 50, 66, 43, 69, 59,
#        42, 61, 40, 71, 51, 65, 53, 46, 45, 39, 47, 62, 34, 35, 29, 55, 60,
#        67, 68, 74, 76, 70, 38, 77])

# %%
# checking the distribution of target variable
df["target"].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# - 1 --> Defective Heart
# - 0 --> Healthy Heart

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# # Spliting The feature and target

# %%
X = df.drop(columns = "target", axis = 1)
Y = df["target"]

# %%
print(X.head())
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal
# 0   0     1
# 1   0     2
# 2   0     2
# 3   0     2
# 4   0     2

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: target, dtype: int64

# %% [markdown]
# # spliting data into training and testing data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, stratify = Y, random_state = 6 )
# without stratify data (i.e: target 1 or 0) may seprate unequally, training data may contant more 1 target then testing data

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (303, 13) (242, 13) (61, 13)

# %% [markdown]
# # model Training

# %% [markdown]
# - Logistic Regression

# %%
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\linear_model\_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# # model Evalution

# %%
predtrain = model.predict(X_train) 
predtest = model.predict(X_test)

# %%
accuracy1 = accuracy_score(Y_train, predtrain)
accuracy2 = accuracy_score(Y_test, predtest)
print("Accuracy score for training data :", accuracy1)
print("Accuracy score for testing data :", accuracy2)
# Out:
# Accuracy score for training data : 0.8553719008264463
# Accuracy score for testing data : 0.8524590163934426

# %%
cm = confusion_matrix(Y_test, predtest)
print(cm)
# Out:
# [[24  4]
#  [ 5 28]]

# %%
plt.figure(figsize = (6,6))
disp = ConfusionMatrixDisplay(cm, display_labels = ["Healthy Heart", "Defective Heart"] )
disp.plot(cmap=plt.cm.Blues)
plt.show()

# %%
print(classification_report(
    Y_test,
    predtest,
    target_names=["Healthy Heart", "Defective Heart"]
))
# Out:
#                  precision    recall  f1-score   support
#
#   Healthy Heart       0.83      0.86      0.84        28
# Defective Heart       0.88      0.85      0.86        33
#
#        accuracy                           0.85        61
#       macro avg       0.85      0.85      0.85        61
#    weighted avg       0.85      0.85      0.85        61

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model2 = DecisionTreeClassifier()

# %%
model2.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Evaluation

# %%
predtrain1 = model2.predict(X_train) 
predtest1 = model2.predict(X_test)
accuracy1_d = accuracy_score(Y_train, predtrain1)
accuracy2_d = accuracy_score(Y_test, predtest1)
print("Accuracy score for training data :", accuracy1_d)
print("Accuracy score for testing data :", accuracy2_d)
# Out:
# Accuracy score for training data : 1.0
# Accuracy score for testing data : 0.819672131147541

# %%
cm = confusion_matrix(Y_test, predtest1) 
print(cm)
plt.figure(figsize = (6,6))
disp = ConfusionMatrixDisplay(cm, display_labels = ["Healthy Heart", "Defective Heart"] )
disp.plot(cmap=plt.cm.Blues) 
plt.show()
# Out:
# [[21  7]
#  [ 4 29]]

# %%
print(classification_report(
    Y_test,
    predtest1,
    target_names=["Healthy Heart", "Defective Heart"]
))
# Out:
#                  precision    recall  f1-score   support
#
#   Healthy Heart       0.84      0.75      0.79        28
# Defective Heart       0.81      0.88      0.84        33
#
#        accuracy                           0.82        61
#       macro avg       0.82      0.81      0.82        61
#    weighted avg       0.82      0.82      0.82        61

# %% [markdown]
# # Random Forest Classification

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model3 = RandomForestClassifier()
model3.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ## Evaluation

# %%
predtrain2 = model3.predict(X_train) 
predtest2 = model3.predict(X_test)
accuracy1_r = accuracy_score(Y_train, predtrain2)
accuracy2_r = accuracy_score(Y_test, predtest2)
print("Accuracy score for training data :", accuracy1_r)
print("Accuracy score for testing data :", accuracy2_r)
# Out:
# Accuracy score for training data : 1.0
# Accuracy score for testing data : 0.8032786885245902

# %%
cm = confusion_matrix(Y_test, predtest2) 
print(cm)
plt.figure(figsize = (6,6))
disp = ConfusionMatrixDisplay(cm, display_labels = ["Healthy Heart", "Defective Heart"] )
disp.plot(cmap=plt.cm.Blues) 
plt.show()
# Out:
# [[23  5]
#  [ 7 26]]

# %%
print(classification_report(
    Y_test,
    predtest2,
    target_names=["Healthy Heart", "Defective Heart"]
))
# Out:
#                  precision    recall  f1-score   support
#
#   Healthy Heart       0.77      0.82      0.79        28
# Defective Heart       0.84      0.79      0.81        33
#
#        accuracy                           0.80        61
#       macro avg       0.80      0.80      0.80        61
#    weighted avg       0.81      0.80      0.80        61

# %% [markdown]
# # Naivae Bayes --> GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model4 = GaussianNB()
model4.fit(X_train, Y_train)
# Out:
# GaussianNB()

# %% [markdown]
# # Evaluation

# %%
predtrain3 = model4.predict(X_train) 
predtest3 = model4.predict(X_test)
accuracy1_n = accuracy_score(Y_train, predtrain3)
accuracy2_n = accuracy_score(Y_test, predtest3)
print("Accuracy score for training data :", accuracy1_n)
print("Accuracy score for testing data :", accuracy2_n)
# Out:
# Accuracy score for training data : 0.8388429752066116
# Accuracy score for testing data : 0.8032786885245902

# %%
cm = confusion_matrix(Y_test, predtest3) 
print(cm)
plt.figure(figsize = (6,6))
disp = ConfusionMatrixDisplay(cm, display_labels = ["Healthy Heart", "Defective Heart"] )
disp.plot(cmap=plt.cm.Blues) 
plt.show()
# Out:
# [[23  5]
#  [ 7 26]]

# %%
print(classification_report(
    Y_test,
    predtest3,
    target_names=["Healthy Heart", "Defective Heart"]
))
# Out:
#                  precision    recall  f1-score   support
#
#   Healthy Heart       0.77      0.82      0.79        28
# Defective Heart       0.84      0.79      0.81        33
#
#        accuracy                           0.80        61
#       macro avg       0.80      0.80      0.80        61
#    weighted avg       0.81      0.80      0.80        61
